# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
import torch.nn as nn

from sklearn.model_selection import train_test_split

# %%
path_full = 'diabetes_data.csv'
path_train = 'diabetesTrain.csv'
path_test = 'diabetesTest.csv'

diabetes_train = pd.read_csv(path_train)
diabetes_train.head()

diabetes_test = pd.read_csv(path_test)
diabetes_test.head()
# Out:
#    age  gender  polyuria  polydipsia  sudden_weight_loss  weakness  \
# 0   40       1         0           1                   0         1
# 1   41       1         1           0                   0         1
# 2   45       1         0           0                   1         1
# 3   55       1         1           1                   0         1
# 4   66       1         1           1                   1         1
#
#    polyphagia  genital_thrush  visual_blurring  itching  irritability  \
# 0           0               0                0        1             0
# 1           1               0                0        1             0
# 2           1               1                0        1             0
# 3           1               0                1        1             0
# 4           0               0                1        1             1
#
#    delayed_healing  partial_paresis  muscle_stiffness  alopecia  obesity  \
# ...

# %%
# Convert the data to PyTorch tensors
diabetes_train = torch.tensor(diabetes_train, dtype=torch.float)
diabetes_test = torch.tensor(diabetes_test, dtype=torch.float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Convert the data to PyTorch tensors
# ----> 2 diabetes_train = torch.tensor(diabetes_train, dtype=torch.float)
#       3 diabetes_test = torch.tensor(diabetes_test, dtype=torch.float)
#
# ValueError: could not determine the shape of object type 'DataFrame'
